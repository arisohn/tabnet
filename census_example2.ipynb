# %%
# !nvidia-smi
# Out:
# Sun Mar  5 11:13:03 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   31C    P0    42W / 400W |      0MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/Colab\ Notebooks/tabnet/
# Out:
# /content/drive/MyDrive/Colab Notebooks/tabnet

# %%
# !pip install wget

# !pip3 install http://download.pytorch.org/whl/cu80/torch-0.3.0.post4-cp36-cp36m-linux_x86_64.whl
# !pip3 install torchvision
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: wget in /usr/local/lib/python3.8/dist-packages (3.2)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: torch-0.3.0.post4-cp36-cp36m-linux_x86_64.whl is not a supported wheel on this platform.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torchvision in /usr/local/lib/python3.8/dist-packages (0.14.1+cu116)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from torchvision) (2.25.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from torchvision) (1.22.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.8/dist-packages (from torchvision) (8.4.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torchvision) (4.5.0)
# Requirement already satisfied: torch==1.13.1 in /usr/local/lib/python3.8/dist-packages (from torchvision) (1.13.1+cu116)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision) (2.10)

# %%
# !pip3 install http://download.pytorch.org/whl/cu80/torch-0.3.0.post4-cp36-cp36m-linux_x86_64.whl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: torch-0.3.0.post4-cp36-cp36m-linux_x86_64.whl is not a supported wheel on this platform.

# %%
from pytorch_tabnet.tab_model import TabNetClassifier

import torch
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import roc_auc_score

import pandas as pd
import numpy as np
np.random.seed(0)


import os
import wget
from pathlib import Path

from matplotlib import pyplot as plt
# %matplotlib inline

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = f"0"

# %%
import torch
torch.__version__
# Out:
# '1.13.1+cu116'

# %% [markdown]
# # Download census-income dataset

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data"
dataset_name = 'census-income'
out = Path(os.getcwd()+'/data/'+dataset_name+'.csv')

# %%
out.parent.mkdir(parents=True, exist_ok=True)
if out.exists():
    print("File already exists.")
else:
    print("Downloading file...")
    wget.download(url, out.as_posix())
# Out:
# File already exists.

# %% [markdown]
# # Load data and split

# %%
train = pd.read_csv(out)
target = ' <=50K'
if "Set" not in train.columns:
    train["Set"] = np.random.choice(["train", "valid", "test"], p =[.8, .1, .1], size=(train.shape[0],))

train_indices = train[train.Set=="train"].index
valid_indices = train[train.Set=="valid"].index
test_indices = train[train.Set=="test"].index

# %% [markdown]
# # Simple preprocessing
#
# Label encode categorical features and fill empty cells.

# %%
nunique = train.nunique()
types = train.dtypes

categorical_columns = []
categorical_dims =  {}
for col in train.columns:
    if types[col] == 'object' or nunique[col] < 200:
        print(col, train[col].nunique())
        l_enc = LabelEncoder()
        train[col] = train[col].fillna("VV_likely")
        train[col] = l_enc.fit_transform(train[col].values)
        categorical_columns.append(col)
        categorical_dims[col] = len(l_enc.classes_)
    else:
        train.fillna(train.loc[train_indices, col].mean(), inplace=True)
# Out:
# 39 73
#  State-gov 9
#  Bachelors 16
#  13 16
#  Never-married 7
#  Adm-clerical 15
#  Not-in-family 6
#  White 5
#  Male 2
#  2174 119
#  0 92
#  40 94
#  United-States 42
#  <=50K 2
# Set 3

# %%
# check that pipeline accepts strings
train.loc[train[target]==0, target] = "wealthy"
train.loc[train[target]==1, target] = "not_wealthy"

# %% [markdown]
# # Define categorical features for categorical embeddings

# %%
unused_feat = ['Set']

features = [ col for col in train.columns if col not in unused_feat+[target]] 

cat_idxs = [ i for i, f in enumerate(features) if f in categorical_columns]

cat_dims = [ categorical_dims[f] for i, f in enumerate(features) if f in categorical_columns]

# %% [markdown]
# # Grouped features
#
# You can now specify groups of feature which will share a common attention.
#
# This may be very usefull for features comming from a same preprocessing technique like PCA for example.

# %%
len(features)
# Out:
# 14

# %%
grouped_features = [[0, 1, 2], [8, 9, 10]]

# %% [markdown]
# # Network parameters

# %%
tabnet_params = {"cat_idxs":cat_idxs,
                 "cat_dims":cat_dims,
                 "cat_emb_dim":2,
                 "optimizer_fn":torch.optim.Adam,
                 "optimizer_params":dict(lr=2e-2),
                 "scheduler_params":{"step_size":50, # how to use learning rate scheduler
                                 "gamma":0.9},
                 "scheduler_fn":torch.optim.lr_scheduler.StepLR,
                 "mask_type":'entmax', # "sparsemax"
                 "grouped_features" : grouped_features,
                 "device_name": "cuda:0"

                }

clf = TabNetClassifier(**tabnet_params
                      )
# Out:
# /content/drive/MyDrive/Colab Notebooks/tabnet/pytorch_tabnet/abstract_model.py:80: UserWarning: Device used : cuda:0
#   warnings.warn(f"Device used : {self.device}")

# %% [markdown]
# # Training

# %%
X_train = train[features].values[train_indices]
y_train = train[target].values[train_indices]

X_valid = train[features].values[valid_indices]
y_valid = train[target].values[valid_indices]

X_test = train[features].values[test_indices]
y_test = train[target].values[test_indices]

# %%
max_epochs = 50 if not os.getenv("CI", False) else 2

# %%
from pytorch_tabnet.augmentations import ClassificationSMOTE
aug = ClassificationSMOTE(p=0.2)

# %%
# This illustrates the warm_start=False behaviour
save_history = []
for _ in range(2):
    clf.fit(
        X_train=X_train, y_train=y_train,
        eval_set=[(X_train, y_train), (X_valid, y_valid)],
        eval_name=['train', 'valid'],
        eval_metric=['auc'],
        max_epochs=max_epochs , patience=20,
        batch_size=1024, virtual_batch_size=128,
        num_workers=0,
        weights=1,
        drop_last=False,
        augmentations=aug, #aug, None
    )
    save_history.append(clf.history["valid_auc"])

assert(np.all(np.array(save_history[0]==np.array(save_history[1]))))
# Out:
# epoch 0  | loss: 0.5892  | train_auc: 0.80731 | valid_auc: 0.79703 |  0:00:05s
# epoch 1  | loss: 0.48449 | train_auc: 0.86412 | valid_auc: 0.86835 |  0:00:07s
# epoch 2  | loss: 0.44796 | train_auc: 0.88062 | valid_auc: 0.88542 |  0:00:09s
# epoch 3  | loss: 0.4313  | train_auc: 0.89512 | valid_auc: 0.89786 |  0:00:10s
# epoch 4  | loss: 0.41469 | train_auc: 0.9025  | valid_auc: 0.90369 |  0:00:12s
# epoch 5  | loss: 0.41165 | train_auc: 0.91018 | valid_auc: 0.91075 |  0:00:14s
# epoch 6  | loss: 0.39266 | train_auc: 0.91456 | valid_auc: 0.91424 |  0:00:16s
# epoch 7  | loss: 0.39082 | train_auc: 0.91784 | valid_auc: 0.91748 |  0:00:18s
# epoch 8  | loss: 0.3838  | train_auc: 0.92084 | valid_auc: 0.92176 |  0:00:20s
# epoch 9  | loss: 0.37487 | train_auc: 0.92255 | valid_auc: 0.92305 |  0:00:21s
# epoch 10 | loss: 0.38291 | train_auc: 0.92317 | valid_auc: 0.92251 |  0:00:23s
# epoch 11 | loss: 0.37393 | train_auc: 0.92503 | valid_auc: 0.92399 |  0:00:25s
# epoch 12 | loss: 0.37112 | train_auc: 0.92613 | valid_auc: 0.92478 |  0:00:27s
# epoch 13 | loss: 0.36586 | train_auc: 0.92671 | valid_auc: 0.92486 |  0:00:29s
# epoch 14 | loss: 0.37013 | train_auc: 0.92809 | valid_auc: 0.92665 |  0:00:30s
# epoch 15 | loss: 0.36877 | train_auc: 0.92907 | valid_auc: 0.92681 |  0:00:32s
# epoch 16 | loss: 0.3683  | train_auc: 0.92874 | valid_auc: 0.92641 |  0:00:34s
# epoch 17 | loss: 0.35904 | train_auc: 0.9297  | valid_auc: 0.92569 |  0:00:36s
# epoch 18 | loss: 0.36552 | train_auc: 0.93111 | valid_auc: 0.92741 |  0:00:38s
# epoch 19 | loss: 0.36872 | train_auc: 0.93158 | valid_auc: 0.92581 |  0:00:40s
# epoch 20 | loss: 0.35917 | train_auc: 0.93226 | valid_auc: 0.92483 |  0:00:41s
# epoch 21 | loss: 0.35821 | train_auc: 0.93363 | valid_auc: 0.9255  |  0:00:43s
# epoch 22 | loss: 0.35756 | train_auc: 0.93383 | valid_auc: 0.92728 |  0:00:45s
# epoch 23 | loss: 0.3599  | train_auc: 0.93443 | valid_auc: 0.92611 |  0:00:47s
# epoch 24 | loss: 0.36135 | train_auc: 0.93303 | valid_auc: 0.92828 |  0:00:49s
# epoch 25 | loss: 0.35576 | train_auc: 0.9342  | valid_auc: 0.92658 |  0:00:51s
# epoch 26 | loss: 0.34356 | train_auc: 0.93447 | valid_auc: 0.92715 |  0:00:52s
# epoch 27 | loss: 0.35395 | train_auc: 0.935   | valid_auc: 0.92916 |  0:00:54s
# epoch 28 | loss: 0.35429 | train_auc: 0.9351  | valid_auc: 0.9282  |  0:00:56s
# epoch 29 | loss: 0.35546 | train_auc: 0.93553 | valid_auc: 0.92775 |  0:00:58s
# epoch 30 | loss: 0.35201 | train_auc: 0.93607 | valid_auc: 0.92829 |  0:01:00s
# epoch 31 | loss: 0.35001 | train_auc: 0.93794 | valid_auc: 0.92857 |  0:01:01s
# epoch 32 | loss: 0.34971 | train_auc: 0.93642 | valid_auc: 0.92839 |  0:01:03s
# epoch 33 | loss: 0.35069 | train_auc: 0.93717 | valid_auc: 0.92592 |  0:01:05s
# epoch 34 | loss: 0.34941 | train_auc: 0.93782 | valid_auc: 0.92672 |  0:01:07s
# epoch 35 | loss: 0.34779 | train_auc: 0.93746 | valid_auc: 0.92616 |  0:01:09s
# epoch 36 | loss: 0.35002 | train_auc: 0.93763 | valid_auc: 0.92604 |  0:01:11s
# epoch 37 | loss: 0.34161 | train_auc: 0.93883 | valid_auc: 0.92668 |  0:01:12s
# epoch 38 | loss: 0.35344 | train_auc: 0.93888 | valid_auc: 0.92652 |  0:01:14s
# epoch 39 | loss: 0.33975 | train_auc: 0.93803 | valid_auc: 0.92565 |  0:01:16s
# epoch 40 | loss: 0.34663 | train_auc: 0.94035 | valid_auc: 0.92679 |  0:01:18s
# epoch 41 | loss: 0.34469 | train_auc: 0.93985 | valid_auc: 0.92694 |  0:01:20s
# epoch 42 | loss: 0.34191 | train_auc: 0.94038 | valid_auc: 0.92413 |  0:01:21s
# epoch 43 | loss: 0.34801 | train_auc: 0.94006 | valid_auc: 0.92601 |  0:01:23s
# epoch 44 | loss: 0.34416 | train_auc: 0.94055 | valid_auc: 0.92473 |  0:01:25s
# epoch 45 | loss: 0.33856 | train_auc: 0.94105 | valid_auc: 0.92507 |  0:01:27s
# epoch 46 | loss: 0.34934 | train_auc: 0.94096 | valid_auc: 0.92516 |  0:01:29s
# epoch 47 | loss: 0.34251 | train_auc: 0.94059 | valid_auc: 0.92493 |  0:01:30s
#
# Early stopping occurred at epoch 47 with best_epoch = 27 and best_valid_auc = 0.92916
# /content/drive/MyDrive/Colab Notebooks/tabnet/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# epoch 0  | loss: 0.5892  | train_auc: 0.80731 | valid_auc: 0.79703 |  0:00:01s
# epoch 1  | loss: 0.48449 | train_auc: 0.86412 | valid_auc: 0.86835 |  0:00:03s
# epoch 2  | loss: 0.44796 | train_auc: 0.88062 | valid_auc: 0.88542 |  0:00:05s
# epoch 3  | loss: 0.4313  | train_auc: 0.89512 | valid_auc: 0.89786 |  0:00:07s
# epoch 4  | loss: 0.41469 | train_auc: 0.9025  | valid_auc: 0.90369 |  0:00:09s
# epoch 5  | loss: 0.41165 | train_auc: 0.91018 | valid_auc: 0.91075 |  0:00:10s
# epoch 6  | loss: 0.39266 | train_auc: 0.91456 | valid_auc: 0.91424 |  0:00:12s
# epoch 7  | loss: 0.39082 | train_auc: 0.91784 | valid_auc: 0.91748 |  0:00:14s
# epoch 8  | loss: 0.3838  | train_auc: 0.92084 | valid_auc: 0.92176 |  0:00:16s
# epoch 9  | loss: 0.37487 | train_auc: 0.92255 | valid_auc: 0.92305 |  0:00:18s
# epoch 10 | loss: 0.38291 | train_auc: 0.92317 | valid_auc: 0.92251 |  0:00:20s
# epoch 11 | loss: 0.37393 | train_auc: 0.92503 | valid_auc: 0.92399 |  0:00:21s
# epoch 12 | loss: 0.37112 | train_auc: 0.92613 | valid_auc: 0.92478 |  0:00:23s
# epoch 13 | loss: 0.36586 | train_auc: 0.92671 | valid_auc: 0.92486 |  0:00:25s
# epoch 14 | loss: 0.37013 | train_auc: 0.92809 | valid_auc: 0.92665 |  0:00:27s
# epoch 15 | loss: 0.36877 | train_auc: 0.92907 | valid_auc: 0.92681 |  0:00:29s
# epoch 16 | loss: 0.3683  | train_auc: 0.92874 | valid_auc: 0.92641 |  0:00:31s
# epoch 17 | loss: 0.35904 | train_auc: 0.9297  | valid_auc: 0.92569 |  0:00:33s
# epoch 18 | loss: 0.36552 | train_auc: 0.93111 | valid_auc: 0.92741 |  0:00:34s
# epoch 19 | loss: 0.36872 | train_auc: 0.93158 | valid_auc: 0.92581 |  0:00:36s
# epoch 20 | loss: 0.35917 | train_auc: 0.93226 | valid_auc: 0.92483 |  0:00:38s
# epoch 21 | loss: 0.35821 | train_auc: 0.93363 | valid_auc: 0.9255  |  0:00:40s
# epoch 22 | loss: 0.35756 | train_auc: 0.93383 | valid_auc: 0.92728 |  0:00:42s
# epoch 23 | loss: 0.3599  | train_auc: 0.93443 | valid_auc: 0.92611 |  0:00:43s
# epoch 24 | loss: 0.36135 | train_auc: 0.93303 | valid_auc: 0.92828 |  0:00:45s
# epoch 25 | loss: 0.35576 | train_auc: 0.9342  | valid_auc: 0.92658 |  0:00:47s
# epoch 26 | loss: 0.34356 | train_auc: 0.93447 | valid_auc: 0.92715 |  0:00:49s
# epoch 27 | loss: 0.35395 | train_auc: 0.935   | valid_auc: 0.92916 |  0:00:51s
# epoch 28 | loss: 0.35429 | train_auc: 0.9351  | valid_auc: 0.9282  |  0:00:53s
# epoch 29 | loss: 0.35546 | train_auc: 0.93553 | valid_auc: 0.92775 |  0:00:54s
# epoch 30 | loss: 0.35201 | train_auc: 0.93607 | valid_auc: 0.92829 |  0:00:56s
# epoch 31 | loss: 0.35001 | train_auc: 0.93794 | valid_auc: 0.92857 |  0:00:58s
# epoch 32 | loss: 0.34971 | train_auc: 0.93642 | valid_auc: 0.92839 |  0:01:00s
# epoch 33 | loss: 0.35069 | train_auc: 0.93717 | valid_auc: 0.92592 |  0:01:02s
# epoch 34 | loss: 0.34941 | train_auc: 0.93782 | valid_auc: 0.92672 |  0:01:04s
# epoch 35 | loss: 0.34779 | train_auc: 0.93746 | valid_auc: 0.92616 |  0:01:05s
# epoch 36 | loss: 0.35002 | train_auc: 0.93763 | valid_auc: 0.92604 |  0:01:07s
# epoch 37 | loss: 0.34161 | train_auc: 0.93883 | valid_auc: 0.92668 |  0:01:09s
# epoch 38 | loss: 0.35344 | train_auc: 0.93888 | valid_auc: 0.92652 |  0:01:11s
# epoch 39 | loss: 0.33975 | train_auc: 0.93803 | valid_auc: 0.92565 |  0:01:13s
# epoch 40 | loss: 0.34663 | train_auc: 0.94035 | valid_auc: 0.92679 |  0:01:15s
# epoch 41 | loss: 0.34469 | train_auc: 0.93985 | valid_auc: 0.92694 |  0:01:16s
# epoch 42 | loss: 0.34191 | train_auc: 0.94038 | valid_auc: 0.92413 |  0:01:18s
# epoch 43 | loss: 0.34801 | train_auc: 0.94006 | valid_auc: 0.92601 |  0:01:20s
# epoch 44 | loss: 0.34416 | train_auc: 0.94055 | valid_auc: 0.92473 |  0:01:22s
# epoch 45 | loss: 0.33856 | train_auc: 0.94105 | valid_auc: 0.92507 |  0:01:24s
# epoch 46 | loss: 0.34934 | train_auc: 0.94096 | valid_auc: 0.92516 |  0:01:26s
# epoch 47 | loss: 0.34251 | train_auc: 0.94059 | valid_auc: 0.92493 |  0:01:27s
#
# Early stopping occurred at epoch 47 with best_epoch = 27 and best_valid_auc = 0.92916
# /content/drive/MyDrive/Colab Notebooks/tabnet/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)

# %%
# plot losses
plt.plot(clf.history['loss'])

# %%
# plot auc
plt.plot(clf.history['train_auc'])
plt.plot(clf.history['valid_auc'])

# %%
# plot learning rates
plt.plot(clf.history['lr'])

# %% [markdown]
# ## Predictions

# %%
preds = clf.predict_proba(X_test)
test_auc = roc_auc_score(y_score=preds[:,1], y_true=y_test)


preds_valid = clf.predict_proba(X_valid)
valid_auc = roc_auc_score(y_score=preds_valid[:,1], y_true=y_valid)

print(f"BEST VALID SCORE FOR {dataset_name} : {clf.best_cost}")
print(f"FINAL TEST SCORE FOR {dataset_name} : {test_auc}")
# Out:
# BEST VALID SCORE FOR census-income : 0.9291648820444631
# FINAL TEST SCORE FOR census-income : 0.9229616267125913

# %%
# check that best weights are used
assert np.isclose(valid_auc, np.max(clf.history['valid_auc']), atol=1e-6)

# %%
clf.predict(X_test)
# Out:
# array(['not_wealthy', 'not_wealthy', 'wealthy', ..., 'not_wealthy',
#        'wealthy', 'wealthy'], dtype='<U11')

# %% [markdown]
# # Save and load Model

# %%
# save tabnet model
saving_path_name = "./tabnet_model_test_1"
saved_filepath = clf.save_model(saving_path_name)
# Out:
# Successfully saved model at ./tabnet_model_test_1.zip

# %%
# define new model with basic parameters and load state dict weights
loaded_clf = TabNetClassifier()
loaded_clf.load_model(saved_filepath)
# Out:
# /content/drive/MyDrive/Colab Notebooks/tabnet/pytorch_tabnet/abstract_model.py:80: UserWarning: Device used : cuda
#   warnings.warn(f"Device used : {self.device}")

# %%
loaded_preds = loaded_clf.predict_proba(X_test)
loaded_test_auc = roc_auc_score(y_score=loaded_preds[:,1], y_true=y_test)

print(f"FINAL TEST SCORE FOR {dataset_name} : {loaded_test_auc}")
# Out:
# FINAL TEST SCORE FOR census-income : 0.9229616267125913

# %%
assert(test_auc == loaded_test_auc)

# %%
loaded_clf.predict(X_test)
# Out:
# array(['not_wealthy', 'not_wealthy', 'wealthy', ..., 'not_wealthy',
#        'wealthy', 'wealthy'], dtype='<U11')

# %% [markdown]
# # Global explainability : feat importance summing to 1

# %%
clf.feature_importances_
# Out:
# array([0.0268236 , 0.0268236 , 0.0268236 , 0.06607823, 0.1140559 ,
#        0.29189012, 0.06271217, 0.06405143, 0.05171666, 0.05171666,
#        0.05171666, 0.0680075 , 0.08394577, 0.01363809])

# %% [markdown]
# # Local explainability and masks

# %%
explain_matrix, masks = clf.explain(X_test)

# %%
fig, axs = plt.subplots(1, 3, figsize=(20,20))


for i in range(3):
    axs[i].imshow(masks[i][:50])
    axs[i].set_title(f"mask {i}")
    axs[i].set_xticklabels(labels = features, rotation=45)
# Out:
# <ipython-input-32-cdd8a56390e0>:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_xticklabels(labels = features, rotation=45)

# %% [markdown]
# # XGB

# %%
from xgboost import XGBClassifier

clf_xgb = XGBClassifier(max_depth=8,
    learning_rate=0.1,
    n_estimators=1000,
    verbosity=0,
    silent=None,
    objective='binary:logistic',
    booster='gbtree',
    n_jobs=-1,
    nthread=None,
    gamma=0,
    min_child_weight=1,
    max_delta_step=0,
    subsample=0.7,
    colsample_bytree=1,
    colsample_bylevel=1,
    colsample_bynode=1,
    reg_alpha=0,
    reg_lambda=1,
    scale_pos_weight=1,
    base_score=0.5,
    random_state=0,
    seed=None,)

clf_xgb.fit(X_train, y_train,
        eval_set=[(X_valid, y_valid)],
        early_stopping_rounds=40,
        verbose=10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-3b888d24393c> in <module>
#      24     seed=None,)
#      25
# ---> 26 clf_xgb.fit(X_train, y_train,
#      27         eval_set=[(X_valid, y_valid)],
#      28         early_stopping_rounds=40,
#
# /usr/local/lib/python3.8/dist-packages/xgboost/core.py in inner_f(*args, **kwargs)
#     618             for k, arg in zip(sig.parameters, args):
#     619                 kwargs[k] = arg
# --> 620             return func(**kwargs)
#     621
#     622         return inner_f
#
# /usr/local/lib/python3.8/dist-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1438                 or not (self.classes_ == expected_classes).all()
#    1439             ):
# -> 1440                 raise ValueError(
#    1441                     f"Invalid classes inferred from unique values of `y`.  "
#    1442                     f"Expected: {expected_classes}, got {self.classes_}"
#
# ValueError: Invalid classes inferred from unique values of `y`.  Expected: [0 1], got ['not_wealthy' 'wealthy']

# %%
preds = np.array(clf_xgb.predict_proba(X_valid))
valid_auc = roc_auc_score(y_score=preds[:,1], y_true=y_valid)
print(valid_auc)

preds = np.array(clf_xgb.predict_proba(X_test))
test_auc = roc_auc_score(y_score=preds[:,1], y_true=y_test)
print(test_auc)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-34-20ec4d206b51> in <module>
# ----> 1 preds = np.array(clf_xgb.predict_proba(X_valid))
#       2 valid_auc = roc_auc_score(y_score=preds[:,1], y_true=y_valid)
#       3 print(valid_auc)
#       4
#       5 preds = np.array(clf_xgb.predict_proba(X_test))
#
# /usr/local/lib/python3.8/dist-packages/xgboost/sklearn.py in predict_proba(self, X, ntree_limit, validate_features, base_margin, iteration_range)
#    1604             class_prob = softmax(raw_predt, axis=1)
#    1605             return class_prob
# -> 1606         class_probs = super().predict(
#    1607             X=X,
#    1608             ntree_limit=ntree_limit,
#
# /usr/local/lib/python3.8/dist-packages/xgboost/sklearn.py in predict(self, X, output_margin, ntree_limit, validate_features, base_margin, iteration_range)
#    1107         with config_context(verbosity=self.verbosity):
#    1108             iteration_range = _convert_ntree_limit(
# -> 1109                 self.get_booster(), ntree_limit, iteration_range
#    1110             )
#    1111             iteration_range = self._get_iteration_range(iteration_range)
#
# /usr/local/lib/python3.8/dist-packages/xgboost/sklearn.py in get_booster(self)
#     647             from sklearn.exceptions import NotFittedError
#     648
# --> 649             raise NotFittedError("need to call fit or load_model beforehand")
#     650         return self._Booster
#     651
#
# NotFittedError: need to call fit or load_model beforehand
